# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
spandan2_cats_faces_64x64_for_generative_models_path = kagglehub.dataset_download('spandan2/cats-faces-64x64-for-generative-models')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Reshape, Flatten, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.models import Sequential
import kagglehub
import cv2
import os

# Set the random seed for reproducibility
tf.random.set_seed(42)

# Download the dataset
path = kagglehub.dataset_download("spandan2/cats-faces-64x64-for-generative-models")

# Load and preprocess the dataset
def load_images(data_path):
    images = []
    for filename in os.listdir(data_path):
        img_path = os.path.join(data_path, filename)
        for file in os.listdir(img_path):
          img = cv2.imread(img_path + '/' + file)
          if img is not None:  # Check if image loaded successfully
              img = cv2.resize(img, (64, 64))  # Resize to 64x64
              img = (img.astype(np.float32) - 127.5) / 127.5  # Scale to [-1, 1]
              images.append(img)
          else:
              pass
    return np.array(images)

# Load images into a NumPy array
cat_images = load_images(path)
print(f"Loaded {cat_images.shape[0]} images of shape {cat_images.shape[1:]}")
# Out:
# Loaded 15747 images of shape (64, 64, 3)

# %%
# Function to generate and save images
def generate_and_save_images(generator, epoch):
    noise = np.random.normal(0, 1, (25, LATENT_DIM))  # Generate 25 random noise vectors
    generated_images = generator.predict(noise)

    # Rescale images from [-1, 1] to [0, 1] for display
    generated_images = 0.5 * generated_images + 0.5

    # Plot the generated images
    plt.figure(figsize=(10, 10))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.imshow(generated_images[i])
        plt.axis("off")
    plt.tight_layout()
    plt.savefig(f"gan_generated.png")  # Save the generated images
    plt.close()

# %%
# Build the generator model
def build_generator():
    model = Sequential()
    model.add(Dense(128 * 16 * 16, activation="relu", input_shape=(100,)))  # Latent dim
    model.add(Reshape((16, 16, 128)))  # Correctly reshape to (16, 16, 128)
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(64 * 64 * 3, activation="tanh"))  # Output size for 64x64 RGB images
    model.add(Reshape((64, 64, 3)))  # Reshape to (64, 64, 3)
    return model

# Build the discriminator model
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(64, 64, 3)))
    model.add(Dense(128, activation=LeakyReLU(0.2)))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation="sigmoid"))  # Output layer for binary classification
    return model

# Create the models
generator = build_generator()
discriminator = build_discriminator()

# Compile the discriminator
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Build the GAN model
discriminator.trainable = False  # Freeze the discriminator while training GAN
gan_input = tf.keras.Input(shape=(100,))
generated_image = generator(gan_input)
gan_output = discriminator(generated_image)

gan = tf.keras.Model(gan_input, gan_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')

# Function to train the GAN
def train_gan(gan, generator, discriminator, dataset, latent_dim, epochs, batch_size):
    for epoch in range(epochs):
        # Train the Discriminator
        idx = np.random.randint(0, dataset.shape[0], batch_size)
        real_images = dataset[idx]

        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        fake_images = generator.predict(noise)

        real_labels = np.ones((batch_size, 1))
        fake_labels = np.zeros((batch_size, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train the Generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_labels = np.ones((batch_size, 1))

        g_loss = gan.train_on_batch(noise, valid_labels)

        # Print the progress
        if epoch:
            print("Epoch: {}, Discriminator Loss: {:.4f}, Generator Loss: {:.4f}".format(epoch, d_loss[0], g_loss))
            generate_and_save_images(generator, epoch)

# Hyperparameters
LATENT_DIM = 100
EPOCHS = 1000
BATCH_SIZE = 64

# Train the GAN
train_gan(gan, generator, discriminator, cat_images, LATENT_DIM, EPOCHS, BATCH_SIZE)

# Generate and save images after training
generate_and_save_images(generator, EPOCHS)
# Out:
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 1, Discriminator Loss: 2.7980, Generator Loss: 32.4923
# 1/1 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 2, Discriminator Loss: 1.2922, Generator Loss: 16.4729
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 3, Discriminator Loss: 1.8004, Generator Loss: 16.3040
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 4, Discriminator Loss: 0.7680, Generator Loss: 14.9946
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 5, Discriminator Loss: 0.8276, Generator Loss: 6.3774
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 6, Discriminator Loss: 0.1074, Generator Loss: 5.4657
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 7, Discriminator Loss: 1.0900, Generator Loss: 5.1275
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 8, Discriminator Loss: 0.8198, Generator Loss: 1.5542
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 9, Discriminator Loss: 0.3972, Generator Loss: 0.4065
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 10, Discriminator Loss: 0.5566, Generator Loss: 6.6129
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 11, Discriminator Loss: 0.5025, Generator Loss: 1.9944
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 12, Discriminator Loss: 0.6906, Generator Loss: 3.9038
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 13, Discriminator Loss: 0.3505, Generator Loss: 3.4581
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 14, Discriminator Loss: 0.0814, Generator Loss: 3.1080
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 15, Discriminator Loss: 1.0646, Generator Loss: 2.8484
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 16, Discriminator Loss: 0.6155, Generator Loss: 5.0027
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 17, Discriminator Loss: 1.0507, Generator Loss: 4.4296
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 18, Discriminator Loss: 1.0634, Generator Loss: 16.1133
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 19, Discriminator Loss: 0.8225, Generator Loss: 18.5765
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 20, Discriminator Loss: 0.8685, Generator Loss: 19.1049
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 21, Discriminator Loss: 3.6239, Generator Loss: 6.3863
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 22, Discriminator Loss: 4.3235, Generator Loss: 7.6914
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 23, Discriminator Loss: 3.5012, Generator Loss: 14.4504
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 24, Discriminator Loss: 2.8147, Generator Loss: 24.3159
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 25, Discriminator Loss: 2.6693, Generator Loss: 30.1794
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 26, Discriminator Loss: 0.8960, Generator Loss: 34.0774
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 27, Discriminator Loss: 2.5520, Generator Loss: 37.2130
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 28, Discriminator Loss: 1.6951, Generator Loss: 47.0467
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 29, Discriminator Loss: 2.0881, Generator Loss: 48.8808
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 30, Discriminator Loss: 1.9939, Generator Loss: 67.6178
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 31, Discriminator Loss: 4.6609, Generator Loss: 67.0643
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 32, Discriminator Loss: 4.9494, Generator Loss: 65.2024
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 33, Discriminator Loss: 3.7248, Generator Loss: 71.3415
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 34, Discriminator Loss: 4.7848, Generator Loss: 80.3685
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 35, Discriminator Loss: 7.8386, Generator Loss: 106.6020
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 36, Discriminator Loss: 11.8697, Generator Loss: 94.1570
# 1/1 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 37, Discriminator Loss: 8.4550, Generator Loss: 95.5764
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 38, Discriminator Loss: 8.8303, Generator Loss: 124.2465
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 39, Discriminator Loss: 10.7204, Generator Loss: 108.7688
# 1/1 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 40, Discriminator Loss: 7.7738, Generator Loss: 131.0135
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 41, Discriminator Loss: 7.3629, Generator Loss: 110.4629
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 42, Discriminator Loss: 6.2069, Generator Loss: 112.1200
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 43, Discriminator Loss: 1.8988, Generator Loss: 105.2729
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 44, Discriminator Loss: 1.3794, Generator Loss: 114.3745
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 45, Discriminator Loss: 2.2820, Generator Loss: 115.8559
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 46, Discriminator Loss: 1.6778, Generator Loss: 81.6737
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 47, Discriminator Loss: 1.3347, Generator Loss: 70.0291
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 48, Discriminator Loss: 1.3388, Generator Loss: 86.3947
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 49, Discriminator Loss: 1.4550, Generator Loss: 63.2869
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 50, Discriminator Loss: 1.2848, Generator Loss: 72.3745
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 51, Discriminator Loss: 1.2858, Generator Loss: 61.1717
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 52, Discriminator Loss: 2.7759, Generator Loss: 75.9304
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 53, Discriminator Loss: 0.9275, Generator Loss: 83.4189
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 54, Discriminator Loss: 0.8656, Generator Loss: 90.0878
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 55, Discriminator Loss: 0.4093, Generator Loss: 82.5384
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 56, Discriminator Loss: 1.3288, Generator Loss: 83.3880
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 57, Discriminator Loss: 0.7438, Generator Loss: 76.5077
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 58, Discriminator Loss: 2.5041, Generator Loss: 98.6965
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 59, Discriminator Loss: 1.7070, Generator Loss: 100.2320
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 60, Discriminator Loss: 1.2192, Generator Loss: 94.1870
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 61, Discriminator Loss: 4.5452, Generator Loss: 125.7709
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 62, Discriminator Loss: 0.2761, Generator Loss: 157.0904
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 63, Discriminator Loss: 3.8210, Generator Loss: 160.2859
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 64, Discriminator Loss: 5.3936, Generator Loss: 185.8461
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 65, Discriminator Loss: 2.7306, Generator Loss: 181.2637
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 66, Discriminator Loss: 1.9290, Generator Loss: 178.0855
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 67, Discriminator Loss: 1.1774, Generator Loss: 164.4008
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 68, Discriminator Loss: 4.1282, Generator Loss: 204.7057
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 69, Discriminator Loss: 7.2974, Generator Loss: 180.3828
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 70, Discriminator Loss: 4.7539, Generator Loss: 176.8867
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 71, Discriminator Loss: 6.2417, Generator Loss: 188.8300
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 72, Discriminator Loss: 2.6514, Generator Loss: 214.5496
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 73, Discriminator Loss: 2.9343, Generator Loss: 210.6833
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 74, Discriminator Loss: 0.8662, Generator Loss: 245.2709
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 75, Discriminator Loss: 1.0160, Generator Loss: 257.2609
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 76, Discriminator Loss: 0.9404, Generator Loss: 245.6214
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 77, Discriminator Loss: 0.3821, Generator Loss: 277.2613
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 78, Discriminator Loss: 0.2211, Generator Loss: 269.0974
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 79, Discriminator Loss: 0.3885, Generator Loss: 278.0792
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 80, Discriminator Loss: 0.7418, Generator Loss: 261.9487
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 81, Discriminator Loss: 0.1196, Generator Loss: 267.8602
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 82, Discriminator Loss: 0.4910, Generator Loss: 270.5921
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 83, Discriminator Loss: 0.0153, Generator Loss: 248.1742
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 84, Discriminator Loss: 0.0337, Generator Loss: 236.7444
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 85, Discriminator Loss: 0.9798, Generator Loss: 217.7524
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 86, Discriminator Loss: 0.9126, Generator Loss: 193.9375
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 87, Discriminator Loss: 0.2444, Generator Loss: 171.0950
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 88, Discriminator Loss: 0.0794, Generator Loss: 180.8794
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 89, Discriminator Loss: 0.5304, Generator Loss: 166.4988
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 90, Discriminator Loss: 0.0687, Generator Loss: 164.2929
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 91, Discriminator Loss: 0.0687, Generator Loss: 132.0294
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 78ms/step
# Epoch: 92, Discriminator Loss: 0.1848, Generator Loss: 138.2140
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 93, Discriminator Loss: 0.2807, Generator Loss: 128.5826
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 94, Discriminator Loss: 0.0095, Generator Loss: 112.1060
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 95, Discriminator Loss: 0.0984, Generator Loss: 110.1151
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 96, Discriminator Loss: 0.0402, Generator Loss: 104.1578
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 97, Discriminator Loss: 0.2116, Generator Loss: 107.1327
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 98, Discriminator Loss: 0.1112, Generator Loss: 97.9922
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 99, Discriminator Loss: 0.4068, Generator Loss: 92.3716
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 100, Discriminator Loss: 0.1116, Generator Loss: 98.1030
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 101, Discriminator Loss: 0.2228, Generator Loss: 95.4206
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 102, Discriminator Loss: 0.0074, Generator Loss: 80.6215
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 103, Discriminator Loss: 0.3403, Generator Loss: 81.4948
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 104, Discriminator Loss: 0.0443, Generator Loss: 86.1951
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 105, Discriminator Loss: 0.0679, Generator Loss: 78.8764
# 1/1 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 106, Discriminator Loss: 0.1222, Generator Loss: 70.5913
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 107, Discriminator Loss: 0.2956, Generator Loss: 68.4234
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 108, Discriminator Loss: 0.5238, Generator Loss: 67.7336
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 109, Discriminator Loss: 0.2649, Generator Loss: 65.7600
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 110, Discriminator Loss: 0.0803, Generator Loss: 69.5737
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 111, Discriminator Loss: 0.2496, Generator Loss: 69.3285
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 112, Discriminator Loss: 0.0064, Generator Loss: 65.9614
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 113, Discriminator Loss: 0.5314, Generator Loss: 72.7783
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 114, Discriminator Loss: 0.1125, Generator Loss: 57.4642
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 115, Discriminator Loss: 0.1568, Generator Loss: 53.7575
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 116, Discriminator Loss: 0.2533, Generator Loss: 64.4556
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 117, Discriminator Loss: 0.1108, Generator Loss: 54.2482
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 118, Discriminator Loss: 0.0352, Generator Loss: 63.8702
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 119, Discriminator Loss: 0.0465, Generator Loss: 62.0405
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 120, Discriminator Loss: 0.0789, Generator Loss: 64.7595
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 121, Discriminator Loss: 0.1545, Generator Loss: 61.5736
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 122, Discriminator Loss: 0.0168, Generator Loss: 62.5446
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 123, Discriminator Loss: 0.0047, Generator Loss: 62.3010
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 124, Discriminator Loss: 0.0421, Generator Loss: 57.8749
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 125, Discriminator Loss: 0.0078, Generator Loss: 58.9520
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 126, Discriminator Loss: 0.0506, Generator Loss: 53.9357
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 127, Discriminator Loss: 0.0310, Generator Loss: 46.8836
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 128, Discriminator Loss: 0.1379, Generator Loss: 43.5144
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 129, Discriminator Loss: 0.0531, Generator Loss: 36.4829
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 130, Discriminator Loss: 0.2022, Generator Loss: 34.8924
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 131, Discriminator Loss: 0.0576, Generator Loss: 39.5173
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 132, Discriminator Loss: 0.0895, Generator Loss: 42.0081
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 133, Discriminator Loss: 0.0233, Generator Loss: 45.6567
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 134, Discriminator Loss: 0.0267, Generator Loss: 39.2499
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 135, Discriminator Loss: 0.1888, Generator Loss: 44.3947
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 136, Discriminator Loss: 0.0580, Generator Loss: 46.6954
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 137, Discriminator Loss: 0.0423, Generator Loss: 46.5554
# 1/1 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 138, Discriminator Loss: 0.0363, Generator Loss: 47.2507
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 139, Discriminator Loss: 0.0147, Generator Loss: 46.4646
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 140, Discriminator Loss: 0.0313, Generator Loss: 45.2363
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 141, Discriminator Loss: 0.0223, Generator Loss: 43.2166
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 142, Discriminator Loss: 0.0038, Generator Loss: 40.7183
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 143, Discriminator Loss: 0.0583, Generator Loss: 42.9498
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 144, Discriminator Loss: 0.0406, Generator Loss: 36.8235
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 145, Discriminator Loss: 0.0695, Generator Loss: 34.6261
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 146, Discriminator Loss: 0.1567, Generator Loss: 37.2273
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 147, Discriminator Loss: 0.0316, Generator Loss: 41.1793
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 148, Discriminator Loss: 0.0049, Generator Loss: 44.1859
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 149, Discriminator Loss: 0.0428, Generator Loss: 45.4279
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 150, Discriminator Loss: 0.0996, Generator Loss: 45.5363
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 151, Discriminator Loss: 0.1195, Generator Loss: 50.8518
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 152, Discriminator Loss: 0.0164, Generator Loss: 50.4193
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 153, Discriminator Loss: 0.0285, Generator Loss: 53.6523
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 154, Discriminator Loss: 0.0137, Generator Loss: 55.2262
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 155, Discriminator Loss: 0.0179, Generator Loss: 48.6437
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 156, Discriminator Loss: 0.0132, Generator Loss: 47.5461
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 157, Discriminator Loss: 0.0187, Generator Loss: 42.9305
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 158, Discriminator Loss: 0.0374, Generator Loss: 42.8696
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 159, Discriminator Loss: 0.0120, Generator Loss: 41.3008
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 160, Discriminator Loss: 0.0373, Generator Loss: 36.6099
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 161, Discriminator Loss: 0.0390, Generator Loss: 34.3815
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 162, Discriminator Loss: 0.0488, Generator Loss: 31.5100
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 163, Discriminator Loss: 0.0155, Generator Loss: 31.7319
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 164, Discriminator Loss: 0.0140, Generator Loss: 27.8429
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 165, Discriminator Loss: 0.0844, Generator Loss: 30.6524
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 166, Discriminator Loss: 0.0539, Generator Loss: 27.7307
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 167, Discriminator Loss: 0.0082, Generator Loss: 31.5293
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 168, Discriminator Loss: 0.0688, Generator Loss: 32.6118
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 80ms/step
# Epoch: 169, Discriminator Loss: 0.0150, Generator Loss: 36.4088
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 170, Discriminator Loss: 0.0684, Generator Loss: 42.5767
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 171, Discriminator Loss: 0.0565, Generator Loss: 41.2502
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 172, Discriminator Loss: 0.0192, Generator Loss: 46.8137
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 173, Discriminator Loss: 0.0206, Generator Loss: 42.8102
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 174, Discriminator Loss: 0.0184, Generator Loss: 46.6569
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 175, Discriminator Loss: 0.0639, Generator Loss: 45.2494
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 176, Discriminator Loss: 0.0137, Generator Loss: 43.0950
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 177, Discriminator Loss: 0.0125, Generator Loss: 39.8438
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 178, Discriminator Loss: 0.0649, Generator Loss: 36.6359
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 179, Discriminator Loss: 0.0261, Generator Loss: 33.6911
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 180, Discriminator Loss: 0.0066, Generator Loss: 33.1400
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 181, Discriminator Loss: 0.0796, Generator Loss: 31.7472
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 182, Discriminator Loss: 0.0914, Generator Loss: 32.5838
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 183, Discriminator Loss: 0.0127, Generator Loss: 29.8622
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 184, Discriminator Loss: 0.1114, Generator Loss: 32.3284
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 185, Discriminator Loss: 0.0454, Generator Loss: 34.4676
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 186, Discriminator Loss: 0.0252, Generator Loss: 36.8544
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 187, Discriminator Loss: 0.0818, Generator Loss: 38.4959
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 188, Discriminator Loss: 0.0436, Generator Loss: 36.7720
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 189, Discriminator Loss: 0.0132, Generator Loss: 38.3275
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 190, Discriminator Loss: 0.0122, Generator Loss: 38.0893
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 191, Discriminator Loss: 0.0508, Generator Loss: 38.2665
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 192, Discriminator Loss: 0.0079, Generator Loss: 35.4767
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 193, Discriminator Loss: 0.0355, Generator Loss: 34.6704
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 194, Discriminator Loss: 0.0043, Generator Loss: 33.5148
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 195, Discriminator Loss: 0.0383, Generator Loss: 31.0529
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 196, Discriminator Loss: 0.0768, Generator Loss: 31.8091
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 197, Discriminator Loss: 0.0140, Generator Loss: 34.0542
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 198, Discriminator Loss: 0.0302, Generator Loss: 34.5693
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 61ms/step
# Epoch: 199, Discriminator Loss: 0.0083, Generator Loss: 33.6886
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 200, Discriminator Loss: 0.0144, Generator Loss: 37.0001
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 201, Discriminator Loss: 0.0055, Generator Loss: 32.3912
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 202, Discriminator Loss: 0.0944, Generator Loss: 37.6122
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 203, Discriminator Loss: 0.0961, Generator Loss: 39.3425
# 1/1 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 204, Discriminator Loss: 0.0180, Generator Loss: 40.3709
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 205, Discriminator Loss: 0.0046, Generator Loss: 44.1533
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 206, Discriminator Loss: 0.0149, Generator Loss: 42.8665
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 207, Discriminator Loss: 0.2023, Generator Loss: 45.7337
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 208, Discriminator Loss: 0.0264, Generator Loss: 45.9201
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 209, Discriminator Loss: 0.0112, Generator Loss: 46.4853
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 210, Discriminator Loss: 0.0246, Generator Loss: 48.0108
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 211, Discriminator Loss: 0.0104, Generator Loss: 42.8458
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 212, Discriminator Loss: 0.1843, Generator Loss: 43.4282
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 213, Discriminator Loss: 0.0268, Generator Loss: 43.9235
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 214, Discriminator Loss: 0.0351, Generator Loss: 45.9632
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 215, Discriminator Loss: 0.0165, Generator Loss: 39.3248
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 216, Discriminator Loss: 0.0086, Generator Loss: 41.8032
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 217, Discriminator Loss: 0.0089, Generator Loss: 39.8527
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 218, Discriminator Loss: 0.0073, Generator Loss: 42.5661
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 219, Discriminator Loss: 0.1046, Generator Loss: 36.5826
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 72ms/step
# Epoch: 220, Discriminator Loss: 0.0081, Generator Loss: 33.2274
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 221, Discriminator Loss: 0.0286, Generator Loss: 35.4705
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 222, Discriminator Loss: 0.0050, Generator Loss: 33.3995
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 223, Discriminator Loss: 0.0278, Generator Loss: 34.5333
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 224, Discriminator Loss: 0.0695, Generator Loss: 32.2631
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 225, Discriminator Loss: 0.1133, Generator Loss: 33.2952
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 226, Discriminator Loss: 0.1818, Generator Loss: 41.6951
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 227, Discriminator Loss: 0.2574, Generator Loss: 41.6446
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 228, Discriminator Loss: 0.0928, Generator Loss: 47.4574
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 229, Discriminator Loss: 0.0640, Generator Loss: 52.4763
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 230, Discriminator Loss: 0.0104, Generator Loss: 58.3410
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 81ms/step
# Epoch: 231, Discriminator Loss: 0.0120, Generator Loss: 52.4882
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 61ms/step
# Epoch: 232, Discriminator Loss: 0.0043, Generator Loss: 57.5047
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 233, Discriminator Loss: 0.0896, Generator Loss: 59.1208
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 234, Discriminator Loss: 0.0173, Generator Loss: 56.0831
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 235, Discriminator Loss: 0.0039, Generator Loss: 56.7125
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 236, Discriminator Loss: 0.0354, Generator Loss: 58.8798
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 237, Discriminator Loss: 0.0024, Generator Loss: 49.8946
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 238, Discriminator Loss: 0.0462, Generator Loss: 54.8971
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 239, Discriminator Loss: 0.0083, Generator Loss: 51.8064
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 240, Discriminator Loss: 0.0079, Generator Loss: 50.3239
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 241, Discriminator Loss: 0.0097, Generator Loss: 49.1778
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 242, Discriminator Loss: 0.0022, Generator Loss: 44.4546
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 243, Discriminator Loss: 0.0500, Generator Loss: 49.6719
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 244, Discriminator Loss: 0.1250, Generator Loss: 47.3318
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 245, Discriminator Loss: 0.0127, Generator Loss: 47.2116
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 246, Discriminator Loss: 0.0264, Generator Loss: 42.9003
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 247, Discriminator Loss: 0.0219, Generator Loss: 40.1785
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 248, Discriminator Loss: 0.0735, Generator Loss: 42.1660
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 249, Discriminator Loss: 0.0279, Generator Loss: 42.5921
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 250, Discriminator Loss: 0.2173, Generator Loss: 45.5966
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 251, Discriminator Loss: 0.0411, Generator Loss: 48.1477
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 252, Discriminator Loss: 0.0193, Generator Loss: 48.7445
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 62ms/step
# Epoch: 253, Discriminator Loss: 0.1340, Generator Loss: 53.1447
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 61ms/step
# Epoch: 254, Discriminator Loss: 0.0040, Generator Loss: 52.4973
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 255, Discriminator Loss: 0.0122, Generator Loss: 48.3646
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 256, Discriminator Loss: 0.0220, Generator Loss: 52.0604
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 257, Discriminator Loss: 0.0063, Generator Loss: 46.9395
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 258, Discriminator Loss: 0.0080, Generator Loss: 44.4383
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 259, Discriminator Loss: 0.1356, Generator Loss: 45.1005
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 260, Discriminator Loss: 0.1075, Generator Loss: 43.4268
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 261, Discriminator Loss: 0.0446, Generator Loss: 45.9438
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 262, Discriminator Loss: 0.0053, Generator Loss: 46.1974
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 263, Discriminator Loss: 0.0224, Generator Loss: 42.7787
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 264, Discriminator Loss: 0.0123, Generator Loss: 45.1310
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 265, Discriminator Loss: 0.0475, Generator Loss: 46.6682
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 266, Discriminator Loss: 0.0203, Generator Loss: 44.8625
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 267, Discriminator Loss: 0.0776, Generator Loss: 43.0557
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 268, Discriminator Loss: 0.0141, Generator Loss: 43.6548
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 269, Discriminator Loss: 0.0060, Generator Loss: 43.1325
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 270, Discriminator Loss: 0.0666, Generator Loss: 46.6951
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 271, Discriminator Loss: 0.0085, Generator Loss: 45.9411
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 272, Discriminator Loss: 0.0013, Generator Loss: 45.1731
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 273, Discriminator Loss: 0.0131, Generator Loss: 42.1106
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 274, Discriminator Loss: 0.0085, Generator Loss: 38.2997
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 275, Discriminator Loss: 0.0707, Generator Loss: 39.2636
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 276, Discriminator Loss: 0.0192, Generator Loss: 39.9263
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 277, Discriminator Loss: 0.0011, Generator Loss: 35.7961
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 278, Discriminator Loss: 0.0050, Generator Loss: 35.7417
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 279, Discriminator Loss: 0.0173, Generator Loss: 35.6790
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 280, Discriminator Loss: 0.0383, Generator Loss: 40.9067
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 281, Discriminator Loss: 0.0752, Generator Loss: 36.4006
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 282, Discriminator Loss: 0.0043, Generator Loss: 37.3801
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 283, Discriminator Loss: 0.0239, Generator Loss: 38.9038
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 284, Discriminator Loss: 0.0100, Generator Loss: 34.9809
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 285, Discriminator Loss: 0.0250, Generator Loss: 34.5544
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 286, Discriminator Loss: 0.0367, Generator Loss: 33.8866
# ...
# Epoch: 905, Discriminator Loss: 0.0412, Generator Loss: 29.4477
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 906, Discriminator Loss: 0.0088, Generator Loss: 29.5848
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 907, Discriminator Loss: 0.1458, Generator Loss: 31.6360
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 908, Discriminator Loss: 0.0040, Generator Loss: 36.4032
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 909, Discriminator Loss: 0.0041, Generator Loss: 36.4919
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 910, Discriminator Loss: 0.0933, Generator Loss: 39.9008
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 911, Discriminator Loss: 0.0890, Generator Loss: 38.4301
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 912, Discriminator Loss: 0.0098, Generator Loss: 40.7246
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 913, Discriminator Loss: 0.2729, Generator Loss: 37.1169
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 914, Discriminator Loss: 0.1503, Generator Loss: 33.6889
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 915, Discriminator Loss: 0.1601, Generator Loss: 39.8609
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 916, Discriminator Loss: 0.0669, Generator Loss: 43.1183
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 917, Discriminator Loss: 0.1844, Generator Loss: 49.5120
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 918, Discriminator Loss: 0.0167, Generator Loss: 47.9062
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 919, Discriminator Loss: 0.0600, Generator Loss: 52.8019
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 920, Discriminator Loss: 0.1616, Generator Loss: 45.0937
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 921, Discriminator Loss: 0.0018, Generator Loss: 41.7949
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 922, Discriminator Loss: 0.0201, Generator Loss: 37.5225
# 1/1 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 923, Discriminator Loss: 0.4238, Generator Loss: 34.5503
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 924, Discriminator Loss: 0.2398, Generator Loss: 31.9841
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 925, Discriminator Loss: 0.0006, Generator Loss: 26.4327
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 926, Discriminator Loss: 0.1274, Generator Loss: 29.1302
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 927, Discriminator Loss: 0.2944, Generator Loss: 26.2014
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 928, Discriminator Loss: 0.1315, Generator Loss: 29.7495
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 929, Discriminator Loss: 0.0094, Generator Loss: 33.1170
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 930, Discriminator Loss: 0.0009, Generator Loss: 37.0472
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 931, Discriminator Loss: 0.3329, Generator Loss: 39.5459
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 932, Discriminator Loss: 0.0297, Generator Loss: 41.7327
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 933, Discriminator Loss: 0.0182, Generator Loss: 47.6154
# 1/1 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 934, Discriminator Loss: 0.0148, Generator Loss: 43.7197
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 935, Discriminator Loss: 0.0160, Generator Loss: 46.1412
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 75ms/step
# Epoch: 936, Discriminator Loss: 0.0418, Generator Loss: 44.4347
# 1/1 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 937, Discriminator Loss: 0.0371, Generator Loss: 39.4489
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 938, Discriminator Loss: 0.0016, Generator Loss: 39.1435
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 939, Discriminator Loss: 0.0314, Generator Loss: 36.5339
# 1/1 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 940, Discriminator Loss: 0.0005, Generator Loss: 30.8069
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 941, Discriminator Loss: 0.0064, Generator Loss: 30.9012
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 942, Discriminator Loss: 0.0107, Generator Loss: 25.2616
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 943, Discriminator Loss: 0.0062, Generator Loss: 22.4253
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 944, Discriminator Loss: 0.0229, Generator Loss: 25.2722
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 945, Discriminator Loss: 0.0328, Generator Loss: 26.7822
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 946, Discriminator Loss: 0.0179, Generator Loss: 28.8446
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 947, Discriminator Loss: 0.0012, Generator Loss: 30.2179
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 948, Discriminator Loss: 0.0005, Generator Loss: 36.3028
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 949, Discriminator Loss: 0.1467, Generator Loss: 37.3763
# 1/1 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 950, Discriminator Loss: 0.0307, Generator Loss: 41.8312
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 951, Discriminator Loss: 0.0922, Generator Loss: 40.4984
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 952, Discriminator Loss: 0.0134, Generator Loss: 39.1027
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 953, Discriminator Loss: 0.0040, Generator Loss: 38.4628
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 954, Discriminator Loss: 0.0520, Generator Loss: 38.7575
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 955, Discriminator Loss: 0.1621, Generator Loss: 38.5409
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 956, Discriminator Loss: 0.0282, Generator Loss: 35.9609
# 1/1 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 957, Discriminator Loss: 0.3046, Generator Loss: 38.6418
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 958, Discriminator Loss: 0.0282, Generator Loss: 36.0323
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 959, Discriminator Loss: 0.0256, Generator Loss: 33.8082
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 960, Discriminator Loss: 0.0012, Generator Loss: 32.1852
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 961, Discriminator Loss: 0.0058, Generator Loss: 30.4594
# 1/1 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 73ms/step
# Epoch: 962, Discriminator Loss: 0.0005, Generator Loss: 24.7634
# 1/1 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 963, Discriminator Loss: 0.0008, Generator Loss: 24.5861
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 964, Discriminator Loss: 0.1341, Generator Loss: 33.2073
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 965, Discriminator Loss: 0.0067, Generator Loss: 42.7365
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 966, Discriminator Loss: 0.0003, Generator Loss: 51.0562
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 967, Discriminator Loss: 0.0319, Generator Loss: 57.8384
# 1/1 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 968, Discriminator Loss: 0.0019, Generator Loss: 59.6534
# 1/1 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 969, Discriminator Loss: 0.1083, Generator Loss: 62.0552
# 1/1 [==============================] - 0s 84ms/step
# 2/2 [==============================] - 0s 74ms/step
# Epoch: 970, Discriminator Loss: 0.0208, Generator Loss: 61.6361
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 971, Discriminator Loss: 0.0393, Generator Loss: 53.4692
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 972, Discriminator Loss: 0.0094, Generator Loss: 51.4532
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 973, Discriminator Loss: 0.0377, Generator Loss: 45.2232
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 71ms/step
# Epoch: 974, Discriminator Loss: 0.0507, Generator Loss: 38.3114
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 975, Discriminator Loss: 0.0013, Generator Loss: 36.8275
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 976, Discriminator Loss: 0.0065, Generator Loss: 33.4540
# 1/1 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 77ms/step
# Epoch: 977, Discriminator Loss: 0.0009, Generator Loss: 32.4699
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 978, Discriminator Loss: 0.0002, Generator Loss: 32.4519
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 979, Discriminator Loss: 0.0007, Generator Loss: 31.3440
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 980, Discriminator Loss: 0.0806, Generator Loss: 29.6458
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 981, Discriminator Loss: 0.0405, Generator Loss: 29.9913
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 982, Discriminator Loss: 0.1046, Generator Loss: 42.4562
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 983, Discriminator Loss: 0.0002, Generator Loss: 56.2390
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 984, Discriminator Loss: 0.0741, Generator Loss: 65.1972
# 1/1 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 70ms/step
# Epoch: 985, Discriminator Loss: 0.1723, Generator Loss: 63.8282
# 1/1 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 986, Discriminator Loss: 0.0704, Generator Loss: 63.1717
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 69ms/step
# Epoch: 987, Discriminator Loss: 0.0650, Generator Loss: 57.7434
# 1/1 [==============================] - 0s 86ms/step
# 2/2 [==============================] - 0s 67ms/step
# Epoch: 988, Discriminator Loss: 0.1913, Generator Loss: 56.7698
# 1/1 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 63ms/step
# Epoch: 989, Discriminator Loss: 0.0031, Generator Loss: 53.9932
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 990, Discriminator Loss: 0.3684, Generator Loss: 55.1491
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 66ms/step
# Epoch: 991, Discriminator Loss: 0.0530, Generator Loss: 46.3156
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 992, Discriminator Loss: 0.0001, Generator Loss: 38.4915
# 1/1 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 993, Discriminator Loss: 0.1449, Generator Loss: 37.5015
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 76ms/step
# Epoch: 994, Discriminator Loss: 0.1961, Generator Loss: 38.5821
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 68ms/step
# Epoch: 995, Discriminator Loss: 0.0025, Generator Loss: 38.7961
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 996, Discriminator Loss: 0.0009, Generator Loss: 40.3173
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 65ms/step
# Epoch: 997, Discriminator Loss: 0.0175, Generator Loss: 41.5749
# 1/1 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 998, Discriminator Loss: 0.0262, Generator Loss: 43.8397
# 1/1 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 64ms/step
# Epoch: 999, Discriminator Loss: 0.0271, Generator Loss: 41.8973
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step

# %%
# Specify the path to save the models
generator.save("generator_model.h5")
discriminator.save("discriminator_model.h5")
gan.save("gan_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp generator_model.h5 /content/drive/MyDrive/

# %%
import tensorflow as tf
import numpy as np

# Paths to the saved models
generator_path = 'generator_model.h5'
discriminator_path = 'discriminator_model.h5'

# Load the previously saved generator and discriminator models
generator = tf.keras.models.load_model(generator_path)
discriminator = tf.keras.models.load_model(discriminator_path)

# Ensure the discriminator is non-trainable while training the GAN
discriminator.trainable = False

# Re-create the GAN model
latent_dim = 100  # Same latent dimension used during training
gan_input = tf.keras.Input(shape=(latent_dim,))
generated_image = generator(gan_input)
gan_output = discriminator(generated_image)

# Compile the GAN
gan = tf.keras.models.load_model("gan_model.h5")
gan.compile(loss='binary_crossentropy', optimizer='adam')

# Function to continue training the GAN
def continue_training_gan(gan, generator, discriminator, dataset, latent_dim, epochs, batch_size):
    for epoch in range(epochs):
        # Train the Discriminator
        idx = np.random.randint(0, dataset.shape[0], batch_size)
        real_images = dataset[idx]

        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        fake_images = generator.predict(noise)

        real_labels = np.ones((batch_size, 1))
        fake_labels = np.zeros((batch_size, 1))

        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(fake_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train the Generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_labels = np.ones((batch_size, 1))

        g_loss = gan.train_on_batch(noise, valid_labels)

        # Print the progress and save the models periodically
        print("Epoch: {}, Discriminator Loss: {:.4f}, Generator Loss: {:.4f}".format(epoch, d_loss[0], g_loss))
        generate_and_save_images(generator, epoch)
        if epoch % 100 == 0:
            # Save the models
            generator.save('generator_model.h5')
            discriminator.save('discriminator_model.h5')
            gan.save('gan_model.h5')

# Parameters for training
EPOCHS = 1000
BATCH_SIZE = 64
continue_training_gan(gan, generator, discriminator, cat_images, latent_dim, EPOCHS, BATCH_SIZE)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
